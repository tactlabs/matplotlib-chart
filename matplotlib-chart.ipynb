# %%
import matplotlib.pyplot as plt
df = pd.read_csv('amazon.csv')
ax = df.plot(x="Amazon", y="Revenue", kind="scatter")
ax.set_ylabel('Revenue')
ax.set_xlabel('Amazon-Revenue-2020')
# Out:
# Text(0.5, 0, 'Amazon-Revenue-2020')

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('amazon.csv')
ax = df.plot(x="Amazon", y="Revenue", kind="bar")
ax.set_ylabel('Revenue')
ax.set_xlabel('Amazon-REvenue-2020')
# Out:
# Text(0.5, 0, 'Amazon-REvenue-2020')

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('mostvisitedsite.csv')
ax = df.plot(x="Website", y="Visitors", kind="pie")
ax.set_ylabel('Visitors')
# (Website)0.youtube1.Facebook2.Wikipedia3.twitter4.amazon

ax.set_xlabel('Monthly global visitors')
# Out:
# Text(0.5, 0, 'Monthly global visitors')

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('topontarioservices.csv')
ax = df.plot(x="Website", y="Review", kind="bar")
ax.set_ylabel('Review')
ax.set_xlabel('Top IT Service in Ontario')
# Out:
# Text(0.5, 0, 'Top IT Service in Ontario')

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('topontarioservices.csv')
ax = df.plot(x="Website", y="Review", kind="scatter")
ax.set_ylabel('Review')
ax.set_xlabel('Top IT Service in Ontario')
# Out:
# Text(0.5, 0, 'Top IT Service in Ontario')

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('topontarioservices.csv')
ax = df.plot(x="Website", y="Review", kind="line")
ax.set_ylabel('Review')
ax.set_xlabel('Top IT Service in Ontario')
# Out:
# Text(0.5, 0, 'Top IT Service in Ontario')

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('topontarioservices.csv')
ax = df.plot(x="Website", y="Review", kind="pie")
# (Website)0.CyberDuo1.DevsData LLC2.Computan3.Folio3 4.Packetlabs Ltd

ax.set_ylabel('Review')
ax.set_xlabel('Top IT Service in Ontario')
# Out:
# Text(0.5, 0, 'Top IT Service in Ontario')

# %%
pip install dash_design_kit
# Out:
# Collecting dash_design_kit
#   Downloading dash_design_kit-0.0.1-py2.py3-none-any.whl (2.8 kB)
# Installing collected packages: dash-design-kit
# Successfully installed dash-design-kit-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('amazon.csv') # iris is a pandas DataFrame
fig = px.scatter(df, x="Amazon", y="Revenue")

fig.show
# Out:
# <bound method BaseFigure.show of Figure({
#     'data': [{'hovertemplate': 'Amazon=%{x}<br>Revenue=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array(['Prime', 'WebServices', 'Alexa', 'Echo', 'Online-store'], dtype=object),
#               'xaxis': 'x',
#               'y': array([25210, 13500, 11000, 11000, 19730]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Amazon'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Revenue'}}}
# })>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('mostvisitedsite.csv')
ax = df.plot(x="Website", y="Visitors", kind="bar")
ax.set_ylabel('Visitors')
ax.set_xlabel('Top Visited Sites')
# Out:
# Text(0.5, 0, 'Top Visited Sites')

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('mostvisitedsite.csv')
ax = df.plot(x="Website", y="Visitors", kind="line")
ax.set_ylabel('Visitors')
ax.set_xlabel('Top Visited Sites')
# Out:
# Text(0.5, 0, 'Top Visited Sites')
